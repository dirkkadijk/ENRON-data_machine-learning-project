# %%
#!/usr/bin/python

""" 
    Starter code for exploring the Enron dataset (emails + finances);
    loads up the dataset (pickled dict of dicts).

    The dataset has the form:
    enron_data["LASTNAME FIRSTNAME MIDDLEINITIAL"] = { features_dict }

    {features_dict} is a dictionary of features associated with that person.
    You should explore features_dict as part of the mini-project, but here's an example to get you started:

    enron_data["SKILLING JEFFREY K"]["bonus"] = 5600000
    
"""

import pickle
enron_data = pickle.load(open("../final_project/final_project_dataset.pkl", "rb"))

#with open("final_project_dataset.pkl", "rb") as data_file:
#    data_dict = pickle.load(data_file)

# %%
type(enron_data)
# Out:
# dict

# %%
#no of people
len(enron_data)
# Out:
# 146

# %%
from pprint import pprint
c = 0
for i in enron_data.items():
    if c < 1:
        c += 1
        pprint(i)
        print('\n')
    else:
        break
# Out:
# ('METTS MARK',
#  {'bonus': 600000,
#   'deferral_payments': 'NaN',
#   'deferred_income': 'NaN',
#   'director_fees': 'NaN',
#   'email_address': 'mark.metts@enron.com',
#   'exercised_stock_options': 'NaN',
#   'expenses': 94299,
#   'from_messages': 29,
#   'from_poi_to_this_person': 38,
#   'from_this_person_to_poi': 1,
#   'loan_advances': 'NaN',
#   'long_term_incentive': 'NaN',
#   'other': 1740,
#   'poi': False,
#   'restricted_stock': 585062,
#   'restricted_stock_deferred': 'NaN',
#   'salary': 365788,
#   'shared_receipt_with_poi': 702,
#   'to_messages': 807,
#   'total_payments': 1061827,
#   'total_stock_value': 585062})

# %%
#no of person of interest according to katie
poi_names = open('../final_project/poi_names.txt', 'r')
fr = poi_names.readlines()                                      # 
print('Number of persons of interest according to Katie:', len(fr[2:]))
#poi_names.close()
# Out:
# Number of persons of interest according to Katie: 35

# %%
type(poi_names)
# Out:
# _io.TextIOWrapper

# %%
type(fr)
# Out:
# list

# %%
fr
# Out:
# ['http://usatoday30.usatoday.com/money/industries/energy/2005-12-28-enron-participants_x.htm\n',
#  '\n',
#  '(y) Lay, Kenneth\n',
#  '(y) Skilling, Jeffrey\n',
#  '(n) Howard, Kevin\n',
#  '(n) Krautz, Michael\n',
#  '(n) Yeager, Scott\n',
#  '(n) Hirko, Joseph\n',
#  '(n) Shelby, Rex\n',
#  '(n) Bermingham, David\n',
#  '(n) Darby, Giles\n',
#  '(n) Mulgrew, Gary\n',
#  '(n) Bayley, Daniel\n',
#  '(n) Brown, James\n',
#  '(n) Furst, Robert\n',
#  '(n) Fuhs, William\n',
#  '(n) Causey, Richard\n',
#  '(n) Calger, Christopher\n',
#  '(n) DeSpain, Timothy\n',
#  '(n) Hannon, Kevin\n',
#  '(n) Koenig, Mark\n',
#  '(y) Forney, John\n',
#  '(n) Rice, Kenneth\n',
#  '(n) Rieker, Paula\n',
#  '(n) Fastow, Lea\n',
#  '(n) Fastow, Andrew\n',
#  '(y) Delainey, David\n',
#  '(n) Glisan, Ben\n',
#  '(n) Richter, Jeffrey\n',
#  '(n) Lawyer, Larry\n',
#  '(n) Belden, Timothy\n',
#  '(n) Kopper, Michael\n',
#  '(n) Duncan, David\n',
#  '(n) Bowen, Raymond\n',
#  '(n) Colwell, Wesley\n',
# ...

# %%
#total value of person
print('Total stock value:', enron_data["PRENTICE JAMES"]["total_stock_value"])

print('Emails from this persons to POI persons:', enron_data['COLWELL WESLEY']['from_this_person_to_poi'])

print('Exercised stocks options by SKILLING JEFFREY K:', enron_data['SKILLING JEFFREY K']['exercised_stock_options'])

print('Total payments to SILLING JEFFREY K', enron_data['SKILLING JEFFREY K']['total_payments'])
# Out:
# Total stock value: 1095040
# Emails from this persons to POI persons: 11
# Exercised stocks options by SKILLING JEFFREY K: 19250000
# Total payments to SILLING JEFFREY K 8682716

# %%
#print een Python dictionary  (=JSON object)
enron_data["PRENTICE JAMES"]
# Out:
# {'salary': 'NaN',
#  'to_messages': 'NaN',
#  'deferral_payments': 564348,
#  'total_payments': 564348,
#  'loan_advances': 'NaN',
#  'bonus': 'NaN',
#  'email_address': 'james.prentice@enron.com',
#  'restricted_stock_deferred': 'NaN',
#  'deferred_income': 'NaN',
#  'total_stock_value': 1095040,
#  'expenses': 'NaN',
#  'from_poi_to_this_person': 'NaN',
#  'exercised_stock_options': 886231,
#  'from_messages': 'NaN',
#  'other': 'NaN',
#  'from_this_person_to_poi': 'NaN',
#  'poi': False,
#  'long_term_incentive': 'NaN',
#  'shared_receipt_with_poi': 'NaN',
#  'restricted_stock': 208809,
#  'director_fees': 'NaN'}

# %%
count_salary = 0
count_email = 0
for key in enron_data.keys():
    if enron_data[key]['salary'] != 'NaN':
        count_salary+=1
    if enron_data[key]['email_address'] != 'NaN':
        count_email+=1
print ('Count of having salary:', count_salary)
print ('Count of emails:', count_email)
# Out:
# count of having salary: 95
# Count of emails: 111

# %%
total_payments_NaN_no = 0
for key in enron_data.keys():
    if enron_data[key]['total_payments'] == 'NaN' :
        total_payments_NaN_no+=1

print ('Total payments with NaN is:', total_payments_NaN_no)

print ('Count of payments with NaN as % of total number of payments:', total_payments_NaN_no*100/146)
# Out:
# Total payments with NaN is: 21
# Count of payments with NaN as % of total number of payments: 14.383561643835616

# %%
total_payments_NaN_no_poi = 0
for key in enron_data.keys():
    if enron_data[key]['total_payments'] == 'NaN' and enron_data[key]['poi']=="true" :
        total_payments_NaN_no_poi+=1

print (total_payments_NaN_no_poi)
print (total_payments_NaN_no_poi*100/146)
# Out:
# 0
# 0.0

# %% [markdown]
# ## Openen in dataframe  (zie github van jeswingeorge - zie in root `Project_analysis_jeswingeorge`)

# %%
# Converting the given pickled Enron data to a pandas dataframe
import pandas as pd 
enron_df = pd.DataFrame.from_records(list(enron_data.values()))
enron_df.head()
# Out:
#    salary to_messages deferral_payments total_payments loan_advances    bonus  \
# 0  365788         807               NaN        1061827           NaN   600000
# 1  267102         NaN           1295738        5634343           NaN  1200000
# 2  170941         NaN               NaN         211725           NaN   350000
# 3     NaN         764               NaN            NaN           NaN      NaN
# 4  243293        1045               NaN         288682           NaN  1500000
#
#               email_address restricted_stock_deferred deferred_income  \
# 0      mark.metts@enron.com                       NaN             NaN
# 1                       NaN                       NaN        -1386055
# 2  steven.elliott@enron.com                       NaN         -400729
# 3     bill.cordes@enron.com                       NaN             NaN
# 4    kevin.hannon@enron.com                       NaN        -3117011
#
#   total_stock_value  ... from_poi_to_this_person exercised_stock_options  \
# ...

# %%
# set the index of df to be the employees series:
employees = pd.Series(list(enron_data.keys()))
enron_df.set_index(employees, inplace=True)
enron_df.head()
# Out:
#                   salary to_messages deferral_payments total_payments  \
# METTS MARK        365788         807               NaN        1061827
# BAXTER JOHN C     267102         NaN           1295738        5634343
# ELLIOTT STEVEN    170941         NaN               NaN         211725
# CORDES WILLIAM R     NaN         764               NaN            NaN
# HANNON KEVIN P    243293        1045               NaN         288682
#
#                  loan_advances    bonus             email_address  \
# METTS MARK                 NaN   600000      mark.metts@enron.com
# BAXTER JOHN C              NaN  1200000                       NaN
# ELLIOTT STEVEN             NaN   350000  steven.elliott@enron.com
# CORDES WILLIAM R           NaN      NaN     bill.cordes@enron.com
# HANNON KEVIN P             NaN  1500000    kevin.hannon@enron.com
#
#                  restricted_stock_deferred deferred_income total_stock_value  \
# ...

# %%
employees
# Out:
# 0                METTS MARK
# 1             BAXTER JOHN C
# 2            ELLIOTT STEVEN
# 3          CORDES WILLIAM R
# 4            HANNON KEVIN P
#                ...
# 141           GRAMM WENDY L
# 142        CAUSEY RICHARD A
# 143       TAYLOR MITCHELL S
# 144    DONAHUE JR JEFFREY M
# 145         GLISAN JR BEN F
# Length: 146, dtype: object

# %%
enron_df.shape
# Out:
# (146, 21)

# %%
enron_data
# Out:
# {'METTS MARK': {'salary': 365788,
#   'to_messages': 807,
#   'deferral_payments': 'NaN',
#   'total_payments': 1061827,
#   'loan_advances': 'NaN',
#   'bonus': 600000,
#   'email_address': 'mark.metts@enron.com',
#   'restricted_stock_deferred': 'NaN',
#   'deferred_income': 'NaN',
#   'total_stock_value': 585062,
#   'expenses': 94299,
#   'from_poi_to_this_person': 38,
#   'exercised_stock_options': 'NaN',
#   'from_messages': 29,
#   'other': 1740,
#   'from_this_person_to_poi': 1,
#   'poi': False,
#   'long_term_incentive': 'NaN',
#   'shared_receipt_with_poi': 702,
#   'restricted_stock': 585062,
#   'director_fees': 'NaN'},
#  'BAXTER JOHN C': {'salary': 267102,
#   'to_messages': 'NaN',
#   'deferral_payments': 1295738,
#   'total_payments': 5634343,
#   'loan_advances': 'NaN',
#   'bonus': 1200000,
#   'email_address': 'NaN',
#   'restricted_stock_deferred': 'NaN',
#   'deferred_income': -1386055,
#   'total_stock_value': 10623258,
#   'expenses': 11200,
# ...
